# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')
from sklearn.metrics import mean_squared_error
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

test_LGBT = pd.read_csv("LGBT_test.csv",header=None)
test_XGBT = pd.read_csv("XGBoost_test.csv",header=None)
test_CABT = pd.read_csv("CatBoost_test.csv",header=None)


y = pd.read_csv("y_test.csv",header=None)

ensemble = (test_LGBT + test_XGBT + test_CABT)/3
LGBT = (test_LGBT*1.0) 
XGBT = (test_XGBT*1.0) 
CABT = (test_CABT*1.0) 


print("LGBT_RMSE:",np.sqrt(mean_squared_error(y, LGBT)))
print("XGBT_RMSE:",np.sqrt(mean_squared_error(y, XGBT)))
print("CABT_RMSE:",np.sqrt(mean_squared_error(y, CABT)))
print()
print("RMSE:",np.sqrt(mean_squared_error(y, ensemble)))
print()
print("RMSE:",19.156933616910674)
# Out:
# LGBT_RMSE: 19.16484244539526
# XGBT_RMSE: 19.468421461361853
# CABT_RMSE: 19.468701992718586
#
# RMSE: 19.156933616910674
#
# RMSE: 19.156933616910674

# %%
sample = pd.read_csv("submit_sample.csv",header=None) 

LGBT_test = pd.read_csv("LGBT_sabmission.csv",header=None) 
XGBT_test = pd.read_csv("XGboost_sabmission.csv",header=None) 
CABT_test = pd.read_csv("Catboost_sabmission.csv",header=None) 


ensemble = (LGBT_test + XGBT_test + CABT_test)/3

sample[1] = ensemble[1]
sample.to_csv("ensemble_sabmission.csv",index=None,header=None)
sample
# Out:
#             0           1
# 0      195942   24.507044
# 1      195943   36.589137
# 2      195944   24.901985
# 3      195945   63.680319
# 4      195946  132.844039
# ...       ...         ...
# 53504  249446   66.327224
# 53505  249447  123.755767
# 53506  249448   69.270670
# 53507  249449   34.077281
# 53508  249450   35.336718
#
# [53509 rows x 2 columns]
